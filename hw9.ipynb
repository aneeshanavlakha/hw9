# %% [markdown]
# # CPSC 330 - Applied Machine Learning
#
# ## Homework 9: Communication
#
# **Due date: See the [Calendar](https://htmlpreview.github.io/?https://github.com/UBC-CS/cpsc330/blob/master/docs/calendar.html)**

# %% [markdown]
# <br><br><br><br>

# %% [markdown]
# <div class="alert alert-info">
#
# ## Submission instructions
# <hr>
# rubric={points:2}
#
# Follow the [homework submission instructions](https://github.com/UBC-CS/cpsc330-2024W1/blob/main/docs/homework_instructions.md).
#
# **You may work in a group on this homework and submit your assignment as a group.** Below are some instructions on working as a group.
# - The maximum group size is 2.
# - Use group work as an opportunity to collaborate and learn new things from each other.
# - Be respectful to each other and make sure you understand all the concepts in the assignment well.
# - It's your responsibility to make sure that the assignment is submitted by one of the group members before the deadline.
# - You can find the instructions on how to do group submission on Gradescope [here](https://help.gradescope.com/article/m5qz2xsnjy-student-add-group-members).
#
#
# When you are ready to submit your assignment do the following:
#
# 1. Run all cells in your notebook to make sure there are no errors by doing `Kernel -> Restart Kernel and Clear All Outputs` and then `Run -> Run All Cells`.
# 2. Notebooks with cell execution numbers out of order or not starting from “1” will have marks deducted. Notebooks without the output displayed may not be graded at all (because we need to see the output in order to grade your work).
# 3. Upload the assignment using Gradescope's drag and drop tool. Check out this [Gradescope Student Guide](https://lthub.ubc.ca/guides/gradescope-student-guide/) if you need help with Gradescope submission.
# 4. Make sure that the plots and output are rendered properly in your submitted file.
# 5. If the .ipynb file is too big and doesn't render on Gradescope, also upload a pdf or html in addition to the .ipynb.

# %% [markdown]
# <br><br><br><br>

# %% [markdown]
# ## Exercise 1: Survival analysis
# <hr>
#
# rubric={points:6}
#
# The following questions pertain to Lecture 21 on survival analysis. We'll consider the use case of customer churn analysis.
#
# 1. What is the problem with simply labeling customers are "churned" or "not churned" and using standard supervised learning techniques?
# 2. Consider customer A who just joined last week vs. customer B who has been with the service for a year. Who do you expect will leave the service first: probably customer A, probably customer B, or we don't have enough information to answer? Briefly explain your answer.
# 3. If a customer's survival function is almost flat during a certain period, how do we interpret that?

# %% [markdown]
# 1. When we treat it as a binary classification problem, we predict whether a customer would churn or not at a particular point in time, when the data was collected. There may be many customers who have not churned yet, so instead we want to analyze the time until an event occurs not whether or not it occurs by a certain time point. This helps account for right censoring.<br>
# 2. probably customer A. the kaplan-meier survival curve we saw indicated that the lowest survival probability was for newer customers (indicated by a steeper curve), possible due to the end of a free trial <br>
# 3. they are less likely to churn in that period.

# %% [markdown]
# <br><br><br><br>

# %% [markdown]
# ## Exercise 2: Communication
# <hr>

# %% [markdown]
# ### 2.1 Blog post
# rubric={points:26}
#
# Write up your analysis from hw5 or any other assignment or your side project on machine learning in a "blog post" or report format. It's fine if you just write it here in this notebook. Alternatively, you can publish your blog post publicly and include a link here. (See exercise 2.3.) The target audience for your blog post is someone like yourself right before you took this course. They don't necessarily have ML knowledge, but they have a solid foundation in technical matters. The post should focus on explaining **your results and what you did** in a way that's understandable to such a person, **not** a lesson trying to teach someone about machine learning. Again: focus on the results and why they are interesting; avoid pedagogical content.
#
# Your post must include the following elements (not necessarily in this order):
#
# - Description of the problem/decision.
# - Description of the dataset (the raw data and/or some EDA).
# - Description of the model.
# - Description your results, both quantitatively and qualitatively. Make sure to refer to the original problem/decision.
# - A section on caveats, describing at least 3 reasons why your results might be incorrect, misleading, overconfident, or otherwise problematic. Make reference to your specific dataset, model, approach, etc. To check that your reasons are specific enough, make sure they would not make sense, if left unchanged, to most students' submissions; for example, do not just say "overfitting" without explaining why you might be worried about overfitting in your specific case.
# - At least 3 visualizations. These visualizations must be embedded/interwoven into the text, not pasted at the end. The text must refer directly to each visualization. For example "as shown below" or "the figure demonstrates" or "take a look at Figure 1", etc. It is **not** sufficient to put a visualization in without referring to it directly.
#
# A reasonable length for your entire post would be **800 words**. The maximum allowed is **1000 words**.

# %% [markdown]
# #### Example blog posts
#
# Here are some examples of applied ML blog posts that you may find useful as inspiration. The target audiences of these posts aren't necessarily the same as yours, and these posts are longer than yours, but they are well-structured and engaging. You are **not required to read these** posts as part of this assignment - they are here only as examples if you'd find that useful.
#
# From the UBC Master of Data Science blog, written by a past student:
#
# - https://ubc-mds.github.io/2019-07-26-predicting-customer-probabilities/
#
# This next one uses R instead of Python, but that might be good in a way, as you can see what it's like for a reader that doesn't understand the code itself (the target audience for your post here):
#
# - https://rpubs.com/RosieB/taylorswiftlyricanalysis
#
# Finally, here are a couple interviews with winners from Kaggle competitions. The format isn't quite the same as a blog post, but you might find them interesting/relevant:
#
# - https://medium.com/kaggle-blog/instacart-market-basket-analysis-feda2700cded
# - https://medium.com/kaggle-blog/winner-interview-with-shivam-bansal-data-science-for-good-challenge-city-of-los-angeles-3294c0ed1fb2

# %% [markdown]
# #### A note on plagiarism
#
# You may **NOT** include text or visualizations that were not written/created by you. If you are in any doubt as to what constitutes plagiarism, please just ask. For more information see the [UBC Academic Misconduct policies](http://www.calendar.ubc.ca/vancouver/index.cfm?tree=3,54,111,959). Please don't copy this from somewhere or ask Generative AI to write it for you 🙏.

# %% [markdown]
# ### WHO'S WORD IS IT ANYWAY? EXPLORING TOPIC MODELING IN NLP
# ##### By Aneesha Navlakha
#
# Natural Language Processing, or NLP, is a massive buzzword that everyone seems to be throwing into their portfolios/job descriptions/marketing strategies. As someone who is new to Machine Learning, I always thought that it was some big fancy algorithm that was reserved for the highest of computer science professionals. I was recently (thankfully) proven wrong. As part of a homework assignment for my Applied ML course, I explored different aspects of NLP that gave me a basic understanding of how it works, as well as it's benefits and drawbacks in the real world. I'd like to share this with you using my assignment as an example. Buckle up! It's going to be a wordy ride.
#
# #### Background
# Natural Language Processing (NLP) is a branch of ML that aims to help computers comprehend, analyze, and produce. Basically, given that humans speak human and computers speak computer, we give computers the tools to understand human enough to perform operations on it. Sort of like giving a child shape-matching games where they have a bunch of random shape blocks and need to learn the difference between the shapes in order to use them.
#
# Say we add new complex shapes into the child's toy collection. Once it has learned details about each shape individually, it can start to draw higher level inferences on all the shapes as a group - it can diferentiate between dissimilar shapes, like a circle and a square, or match common shapes and group them into clusters like squares and rectangles in one group (4 sides) and triangles in another (3 sides). In other words, NLP is useful in many ways, one being to find the common themes in a large corpus of documents, especially when the corpus is too large to manually sift through. In my assignments, my goal was to find the common themes in a large corpus of documents - the "20 newsgroups text dataset" - using scikit-learn's LatentDirichletAllocation (LDA) NLP model. This process of discovering high-level themes in a large collection of texts is called "Topic modeling".
#
# As my assignment said, atypical to a regular corpus, the 20 newsgroups text dataset is already labeled with themes (e.g., sports, hardware, religion), which I could use to cross-check the topics discovered by my models. The themes I used are 'alt.atheism', 'comp.graphics', 'comp.windows.x',  'rec.sport.baseball', 'rec.sport.hockey', 'soc.religion.christian', 'talk.politics.guns', and 'talk.politics.mideast'. See Figure 1 Below.

# %%
from IPython.display import Image

Image("img/Figure 1.png")

# %% [markdown]
# #### Preprocessing
# These are a few of the sentences in the corpus (Figure 2)

# %%
Image("img/Figure 2.png")

# %% [markdown]
# As you can see, the sentences in this corpus make little sense, with a lot of unnecessary text, characters, and spaces. It makes the sentences harder to work with so before I handed the corpus over the the LDA model, I cleaned it up in a process called "pre-processing". For this, I used SpaCy, a popular NLP library that is commonly used to pre-process text. I defined a function that did the following:
#
# - replaced newlines/tabs with spaces
# - cleaned the text by removing irrelevant tokens
# - normalized text by replacing URLs, emails, and numbers with placeholders
# - simplified words by lemmatizing them
# - ensured consistency through lower-casing
# - output the cleaned and processed text as a string
#
# Note: "Lemmatization" is a process that analyzes a word's context and morphology to return the root form (lemma), ensuring the base form is a valid word in the language, e.g., the lemma of both "carrying" and "carried" is "carry". "Word tokenization" splits sentences into words.
#
# The text_pp column in Figure 3 below shows the cleaned up text.

# %%
Image("img/Figure 3.png")

# %% [markdown]
# #### Topic Modelling
# Finally, I passed my pre-processed text into the LDA model to perform topic modeling! As a reminder, topic modeling is the process of discovering high-level themes in a large collection of texts. The text was now clean enough to work with i.e., the splinters and dust had been removed from the shapes so now we could start to find themes. The sentences were first converted into individual words to get the most important information.
#
# LDA allowed me to explore and identify the ideal number of themes to sort the words into. Using a range of values for the the n_components hyper-parameter in LDA, I tried values ranging from 1 - 50. For some reason, however, the model kept recommending the largest number so I picked 7 after inspecting the contents of topics at each value in the next step. This is a potential shortcoming that I will discuss at the end of my article. Figure 4 below shows how many words were in each of the 7 topics (ignore the fancy axis names).

# %%
Image("img/Figure 4.png")

# %% [markdown]
# #### Word Topic Association
# Having settled on 7 topics, I used the mglearn helper package to get the top 10 words in each category. Figure 5 below shows these words.

# %%
Image("img/Figure 5.png")

# %% [markdown]
# Using my intuition, I named each of the topics:
#
# - TOPIC 0: Middle east geo-politics
# - TOPIC 1: Religion and belief
# - TOPIC 2: Technology
# - TOPIC 3: University and academics
# - TOPIC 4: Digital media
# - TOPIC 5: Israel-Palestine conflict
# - TOPIC 6: Security
#
# This process showed me what the prominent words in each cluster are. The features of the different toys, e.g., how many sides, has been extracted and we have defined the appropriate number of clusters based on that.
#
# #### Document Topic Association
# But does each document only contain one theme or are there some which are a mixture of multiple themes? Can a shape with 2 sets of parallel sides be both a quadrilateral, and a rectangle?
#
# The document_topic[] function of LDA gives you a percentage of how similar each document in your corpus is to each theme (topic) you defined. I found the document_topic for the first 5 documents (sentences) i.e., document_topics[:5], in our original table . This is what I got:
#
# - Document 0 corresponds to Topic 0 the most at 66% and Topic 1 at 32%
# - Document 1 corresponds to Topic 2 the most at 74%
# - Document 2 corresponds to Topic 1 the most at 61% and Topic 2 at 32%
# - Document 3 corresponds to Topic 2 the most at 70%
# - Document 4 corresponds to Topic 0 the most at 85%
#
# There are only some differences from the pattern of assignments that the corpus had by default: document 2 that was earlier classified as comp.graphics is now mostly religion and belief. The remaining documents seem to be classified along the same lines.
#
# This process showed me that there are documents which are a mixture of multiple themes.
#
# #### Learnings
# 1. n_components kept recommending the highest value in the range I provided rather than converging on a single value. So I don't actually know if 7 was the optimal number of topics that captured the nuanced differences between my documents.
# 2. I think I had space to name the 7 topics differently - the names I gave it may be misleading and 10 words may not have been enough to get a true feel of the general theme of the topic. there were certain words that I chose to ignore as I didn't understand where they came from, like "san" in Topic 3.
# 3. I also think m text pre-processing was more complicated than it needed to be. In trying to be thorough, I think I covered more text caveats than needed.

# %% [markdown]
# <br><br>

# %% [markdown]
# ### 2.2 Effective communication technique
# rubric={points:4}
#
# Describe one effective communication technique that you used in your post, or an aspect of the post that you are particularly satisfied with. (Max 3 sentences.)

# %% [markdown]
# Bottom-up communication. I attempted to explain NLP as a whole first, then Topic modeling, and then the specific processes used within it. I am fairly satisfied with the flow of my document as I think I laid out my ideas clearly enough. I also used a running analogy which I think helps clear up certain concepts.

# %% [markdown]
# <br><br>

# %% [markdown]
# ### (optional, not for marks) 2.3
#
# Publish your blog post from 1.1 publicly using a tool like [Quarto](https://quarto.org/), or somewhere like medium.com, and paste a link here. Be sure to pick a tool in which code and code output look reasonable. This link could be a useful line on your resume!

# %% [markdown]
# <br><br><br><br>

# %% [markdown]
# ## Exercise 3: Your takeaway from the course
# rubric={points:2}
#
# **Your tasks:**
#
# - Reflect on your journey through this course. Please identify and elaborate on at least three key concepts or experiences where you had an "aha" moment. How would you use the concepts learned in this course in your personal projects or how would you approach your past projects differently based on the insights gained in this course? We encourage you to dig deep and share your genuine reflections.
#
# > Please write thoughtful answers. We are looking forward to reading them 🙂.

# %% [markdown]
# 1. the very beginning when we learned about the basic concept behind how an ML model works, both supervised and unsupervised. it just felt so intuitive that this sort of algorithm exists and had endless possibilities. <br>
# 2. clustering. I loved he visual aspect of k-means and db-scan. it was so much easier for me to understand the waythe models work<br>
# 3. transformations and pipelines. the repeated process of identifying feature types, defining a preprocessor and hen using it with a model clarified many earlier concepts for me <br>
# 4. I also liked the more application-based units like NLP and recommender systems. it opened up many aspects of ML that I hadn't thought of
#
# I think I can use these concepts in my COGS 402 final project next term, or in any job I work in the future as the world is going towards a place where you need this knowledge to succeed. I do not plan to become a software developer, I am more interested in UX and product research but this information is key for me to understand programs other teams are working on, and be able to critically question them. it's also a very logical way of thinking that can be applied to regular decision making.

# %% [markdown]
# <br><br><br><br>

# %% [markdown]
# **Before submitting your assignment, please make sure you have followed all the instructions in the Submission instructions section at the top.**

# %% [markdown]
# ### Congratulations 👏👏
#
# That's all for the assignments! Congratulations on finishing all homework assignments!

# %%
from IPython.display import Image

Image("img/eva-congrats.png")
